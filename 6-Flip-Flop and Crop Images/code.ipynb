# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread("giraffe-Kenya.png")
rgb_image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %% [markdown]
# Flip

# %%
flip_horizontal=cv2.flip(image,1)
flip_vertical=cv2.flip(image,0)
flip_both=cv2.flip(image,-1)

# %%
titles=["Original Image","Horizontal Flip","Vertical Flip","Flip both axis"]
images=[image_rgb,
        cv2.cvtColor(flip_horizontal,cv2.COLOR_BGR2RGB),
        cv2.cvtColor(flip_vertical,cv2.COLOR_BGR2RGB),
        cv2.cvtColor(flip_both,cv2.COLOR_BGR2RGB)
        ]

# %%
plt.figure(figsize=(12,8))
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis("off")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Rotate

# %%
rotate_90_clockwise=cv2.rotate(image_rgb,cv2.ROTATE_90_CLOCKWISE)
rotate_90_counterclockwise=cv2.rotate(image_rgb,cv2.ROTATE_90_COUNTERCLOCKWISE)
rotate_180=cv2.rotate(image_rgb,cv2.ROTATE_180)
titles=["Original Image","90 clockwise","90 counterClockwise","180 degree"]
images=[image_rgb,rotate_90_clockwise,rotate_90_counterclockwise,rotate_180]

# %%
plt.figure(figsize=(12,8))
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis("off")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Cropping an image

# %%
print(image_rgb.shape)
# Out:
# (1600, 1067, 3)

# %%
print(type(image_rgb))
# Out:
# <class 'numpy.ndarray'>

# %%
x_start,y_start=400,300
x_end,y_end=800,900
cropped_image=image_rgb[y_start:y_end,x_start:x_end]

# %%
plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2,)
plt.imshow(cropped_image)
plt.title("Cropped Image")
plt.axis("off")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
